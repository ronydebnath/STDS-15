# %%
import pandas as pd
pd.set_option('display.max_columns', 1000)  # or 1000

# %%
df_org = pd.DataFrame({})

# Load the dataset
df_org = pd.read_csv("heart_2020_cleaned.csv")

# %%
df_org.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
# Check for null values

df_org.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
print(df_org.dtypes)
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime           float64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %%
df_org.shape
# Out:
# (319795, 18)

# %%
# Check for duplicates

df_org.duplicated().sum()
# Out:
# 18078

# %% [markdown]
# Encoding

# %%
from sklearn.preprocessing import LabelEncoder

df_enc = pd.DataFrame({})

# Load the dataset
df_enc = pd.read_csv("heart_2020_cleaned.csv")

# %%
df_enc.head(10)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
# 5          Yes  28.87     Yes              No     No             6.0
# 6           No  21.63      No              No     No            15.0
# 7           No  31.64     Yes              No     No             5.0
# 8           No  26.45      No              No     No             0.0
# 9           No  40.69      No              No     No             0.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0          30.0          No  Female        55-59  White
# 1           0.0          No  Female  80 or older  White
# ...

# %%
#categorial
le = LabelEncoder()
label_mappings = {}

# Select the columns you want to label encode
columns_to_encode = ['HeartDisease', 'Smoking', 'AlcoholDrinking', 'AgeCategory', 'Stroke', 'DiffWalking',
                     'Race', 'Sex', 'PhysicalActivity', 'Asthma', 'KidneyDisease', 'SkinCancer', 'GenHealth', 'Diabetic']

for col_name in columns_to_encode:
    df_enc[col_name] = le.fit_transform(df_enc[col_name])
    #Create a mapping dictionary for the current column
    label_mappings[col_name] = dict(zip(df_org[col_name], df_enc[col_name]))

# %%
df_enc.head(10)
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
# 5             1  28.87        1                0       0             6.0
# 6             0  21.63        0                0       0            15.0
# 7             0  31.64        1                0       0             5.0
# 8             0  26.45        0                0       0             0.0
# 9             0  40.69        0                0       0             0.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0          30.0            0    0            7     5         2
# ...

# %%
for col_name, mapping in label_mappings.items():
    print(f"Mapping for {col_name}:")
    print(mapping)
# Out:
# Mapping for HeartDisease:
# {'No': 0, 'Yes': 1}
# Mapping for Smoking:
# {'Yes': 1, 'No': 0}
# Mapping for AlcoholDrinking:
# {'No': 0, 'Yes': 1}
# Mapping for AgeCategory:
# {'55-59': 7, '80 or older': 12, '65-69': 9, '75-79': 11, '40-44': 4, '70-74': 10, '60-64': 8, '50-54': 6, '45-49': 5, '18-24': 0, '35-39': 3, '30-34': 2, '25-29': 1}
# Mapping for Stroke:
# {'No': 0, 'Yes': 1}
# Mapping for DiffWalking:
# {'No': 0, 'Yes': 1}
# Mapping for Race:
# {'White': 5, 'Black': 2, 'Asian': 1, 'American Indian/Alaskan Native': 0, 'Other': 4, 'Hispanic': 3}
# Mapping for Sex:
# {'Female': 0, 'Male': 1}
# Mapping for PhysicalActivity:
# {'Yes': 1, 'No': 0}
# Mapping for Asthma:
# {'Yes': 1, 'No': 0}
# Mapping for KidneyDisease:
# {'No': 0, 'Yes': 1}
# Mapping for SkinCancer:
# {'Yes': 1, 'No': 0}
# Mapping for GenHealth:
# {'Very good': 4, 'Fair': 1, 'Good': 2, 'Poor': 3, 'Excellent': 0}
# Mapping for Diabetic:
# {'Yes': 2, 'No': 0, 'No, borderline diabetes': 1, 'Yes (during pregnancy)': 3}

# %%
df_enc.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0          30.0            0    0            7     5         2
# 1           0.0            0    0           12     5         0
# 2          30.0            0    1            9     5         2
# 3           0.0            0    0           11     5         0
# 4           0.0            1    0            4     5         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
import numpy as np

#integer
num_cols = ['MentalHealth', 'PhysicalHealth', 'SleepTime']

for i in num_cols:
    df_enc[i] = df_enc[i].astype(np.int64)

# %%
df_enc.dtypes
# Out:
# HeartDisease          int64
# BMI                 float64
# Smoking               int32
# AlcoholDrinking       int32
# Stroke                int32
# PhysicalHealth        int64
# MentalHealth          int64
# DiffWalking           int32
# Sex                   int32
# AgeCategory           int32
# Race                  int32
# Diabetic              int32
# PhysicalActivity      int32
# GenHealth             int32
# SleepTime             int64
# Asthma                int32
# KidneyDisease         int32
# SkinCancer            int32
# dtype: object

# %%
df_enc.head(10)
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0               3
# 1             0  20.34        0                0       1               0
# 2             0  26.58        1                0       0              20
# 3             0  24.21        0                0       0               0
# 4             0  23.71        0                0       0              28
# 5             1  28.87        1                0       0               6
# 6             0  21.63        0                0       0              15
# 7             0  31.64        1                0       0               5
# 8             0  26.45        0                0       0               0
# 9             0  40.69        0                0       0               0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0            30            0    0            7     5         2
# ...

# %%
# # encode binary attributes
# df_trns['AgeCategory'] = df_trns['AgeCategory'].map({'55-59': 55, '80 or older': 80, '65-69': 65, '75-79': 75, '40-44': 40, '70-74': 70, '60-64': 60, '50-54': 50, '45-49': 45, '18-24': 18, '35-39': 35, '30-34': 30, '25-29': 25})

# print(df_trns['AgeCategory'])


# # encode binary attributes
# df_trns['Sex'] = df_trns['Sex'].map({'Male': 1, 'Female': 2})

# print(df_trns['Sex'])

# # encode binary attributes
# df_trns['Race'] = df_trns['Race'].map({'White': 1, 'Black': 2, 'Asian': 3, 'American Indian/Alaskan Native': 4, 'Other': 6, 'Hispanic': 5})

# print(df_trns['Race'])


# # encode binary attributes
# df_trns['Diabetic'] = df_trns['Diabetic'].map({'No': 0, 'No, borderline diabetes': 1, 'Yes (during pregnancy)': 2, 'Yes': 3})

# print(df_trns['Diabetic'])


# # encode binary attributes
# df_trns['GenHealth'] = df_trns['GenHealth'].map({'Poor': 0, 'Fair': 1, 'Good': 2, 'Very good': 3, 'Excellent': 4})

# print(df_trns['GenHealth'])

# %% [markdown]
# Logistic Regression

# %% [markdown]
# The dataset 'df' now contains all attributes encoded with one-hot encoding for categorical variables
# and binary encoding for binary variables

# %%
df = pd.DataFrame({})

df = df_enc

# %%
df.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0               3
# 1             0  20.34        0                0       1               0
# 2             0  26.58        1                0       0              20
# 3             0  24.21        0                0       0               0
# 4             0  23.71        0                0       0              28
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0            30            0    0            7     5         2
# 1             0            0    0           12     5         0
# 2            30            0    1            9     5         2
# 3             0            0    0           11     5         0
# 4             0            1    0            4     5         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score

# Function for Logistic Regression
def perform_logistic_regression(df, target_column, test_size=0.2, random_state=None):
    """
    Perform logistic regression for binary classification.

    Parameters:
    - df: pandas DataFrame containing the dataset.
    - target_column: Name of the column to be predicted (the target variable).
    - test_size: Proportion of the dataset to include in the test split (default is 0.2).
    - random_state: Seed for random number generation (optional).

    Returns:
    - model: Fitted logistic regression model.
    - evaluation_results: Dictionary containing evaluation metrics.
    - confusion_matrix: Confusion matrix as a 2x2 NumPy array.
    """
    # Split the dataset into features and target variable
    X = df.drop(columns=[target_column])
    y = df[target_column]

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    # Standardize the features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # Create and train the logistic regression model
    model = LogisticRegression()
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred)
    classification_rep = classification_report(y_test, y_pred, output_dict=True)

    # Create a confusion matrix
    confusion_mat = confusion_matrix(y_test, y_pred)

    # Create a summary of the evaluation results
    evaluation_results = {
        "Accuracy": accuracy,
        "ROC-AUC": roc_auc,
        "Classification Report": classification_rep
    }

    return model, evaluation_results, confusion_mat

# %%
# Call the function
model, evaluation_results, confusion_mat = perform_logistic_regression(df, 'HeartDisease')

# Print the evaluation results
print("Logistic Regression Model Evaluation:")
print(f"Accuracy: {evaluation_results['Accuracy']:.4f}")
print(f"ROC-AUC: {evaluation_results['ROC-AUC']:.4f}")
print("Classification Report:")
print(evaluation_results['Classification Report'])
print("Confusion Matrix:")
print(confusion_mat)
# Out:
# Logistic Regression Model Evaluation:
# Accuracy: 0.9146
# ROC-AUC: 0.5426
# Classification Report:
# {'0': {'precision': 0.9203199898415924, 'recall': 0.9924176294394523, 'f1-score': 0.9550100060118426, 'support': 58425}, '1': {'precision': 0.5370950888192267, 'recall': 0.09288037585833032, 'f1-score': 0.1583731320289632, 'support': 5534}, 'accuracy': 0.9145859065964134, 'macro avg': {'precision': 0.7287075393304095, 'recall': 0.5426490026488914, 'f1-score': 0.5566915690204028, 'support': 63959}, 'weighted avg': {'precision': 0.8871617696965343, 'recall': 0.9145859065964134, 'f1-score': 0.8860816540891852, 'support': 63959}}
# Confusion Matrix:
# [[57982   443]
#  [ 5020   514]]
